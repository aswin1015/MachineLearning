# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# %%
data=pd.read_csv(r"C:\Users\Admin\homeprices.csv")
data
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.xlabel("AREA")
plt.ylabel("Price")
plt.scatter(data['area'],data['price'],c='r',marker='+')
plt.plot(data.area,rg.predict(data[['area']]),color='blue')

# %%
rg=LinearRegression()
rg.fit(data[['area']],data.price)
# Out:
# LinearRegression()

# %%
rg.predict(np.array((5000)).reshape(-1,1))
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
rg.coef_
# Out:
# array([135.78767123])

# %%
rg.intercept_
# Out:
# 180616.43835616432

# %%
135.78767123*3300+180616.43835616432
# Out:
# 628715.7534151643

# %%
d=pd.read_csv(r"C:\Users\Admin\areas.csv")
d
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
d.head()
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300
# 3  3540
# 4  4120

# %%
p=rg.predict(d)

# %%
d['prices']=p
d.to_csv(r"C:\Users\Admin\areas.csv")

# %%
d1=pd.read_csv(r"C:\Users\Admin\canada_per_capita_income.csv")
d1
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
plt.scatter(d1.year,d1['per capita income (US$)'])

# %%
rg.fit(d1[['year']],d1['per capita income (US$)'])
# Out:
# LinearRegression()

# %%
plt.scatter(d1.year,d1['per capita income (US$)'])
plt.plot(d1.year,rg.predict(d1[['year']]),c="red")

# %%
rg.predict(np.array((2036)).reshape(-1,1))
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([54544.13529798])
